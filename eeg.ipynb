# %%
# !cd '/content/drive/MyDrive/Colab_Notebooks/ML_Work/ncp/classical_ml/EEG'

# %%
import pandas as pd

from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import os 

import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Activation
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import keras

# %%
# %cd '/content/drive/MyDrive/Colab_Notebooks/ML_Work/ncp/classical_ml/EEG'
# Out:
# /content/drive/MyDrive/Colab_Notebooks/ML_Work/ncp/classical_ml/EEG

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab_Notebooks/ML_Work/ncp/classical_ml/EEG

# %%
df = pd.read_csv('emotions.csv')
df.head()
# Out:
#    # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  mean_d_1_a  \
# 0        4.62      30.3    -356.0      15.6      26.3       1.070       0.411
# 1       28.80      33.1      32.0      25.8      22.8       6.550       1.680
# 2        8.90      29.4    -416.0      16.7      23.7      79.900       3.360
# 3       14.90      31.6    -143.0      19.8      24.3      -0.584      -0.284
# 4       28.30      31.3      45.2      27.3      24.5      34.800      -5.790
#
#    mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_741_b  fft_742_b  fft_743_b  \
# 0      -15.70        2.06        3.15  ...       23.5       20.3       20.3
# 1        2.88        3.83       -4.82  ...      -23.3      -21.8      -21.8
# 2       90.20       89.90        2.03  ...      462.0     -233.0     -233.0
# 3        8.82        2.30       -1.97  ...      299.0     -243.0     -243.0
# 4        3.06       41.40        5.52  ...       12.0       38.1       38.1
#
# ...

# %%
dfx = df.drop('label',axis=1)
dfy = df['label']

# %%
le = LabelEncoder()
dfy = le.fit_transform(dfy)

# %%
X_train,X_test, y_train,y_test = train_test_split(dfx, dfy, test_size = 0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-86ec9d4cbaef> in <module>
# ----> 1 X_train,X_test, y_train,y_test = train_test_split(dfx, dfy, test_size = 0.2)
#
# NameError: name 'train_test_split' is not defined

# %%
#clf = RandomForestClassifier(max_depth=2, random_state=0)
clf = RandomForestClassifier()
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        70
#            1       1.00      1.00      1.00        64
#            2       1.00      0.99      0.99        80
#
#     accuracy                           1.00       214
#    macro avg       1.00      1.00      1.00       214
# weighted avg       1.00      1.00      1.00       214

# %%
#Model 1
model = Sequential()
model.add(Dense(256, input_shape=(2548,), activation='softmax'))
model.add(Dropout(0.2))
model.add(Dense(128, input_shape=(2548,), activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='softmax'))
model.add(Dropout(0.2))

model.add(Dense(32, activation='tanh'))
model.add(Dense(3, activation='softmax'))

# %%
optimizer = keras.optimizers.Adam(lr=0.0001)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)

# %%
# Plot the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()
